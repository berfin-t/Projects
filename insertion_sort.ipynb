# %% [markdown]
# ## [22,27,16,2,18,6] -> Insertion Sort

# %% [markdown]
# ## 1.

# %% [markdown]
# [2,27,16,22,18,6] =>
# [2,6,16,22,18,27] =>
# [2,6,16,18,22,27]

# %% [markdown]
# ## 2.

# %% [markdown]
# Best Case: O(n), Average Case: O(n2), Worst Case: O(n2)

# %% [markdown]
# ## 3.

# %% [markdown]
# 18 sayısı Average Case: O(n2) kapsamına girer.

# %% [markdown]
# [2,3,5,8,7,9,4,15,6] => [2,3,4,8,7,9,5,15,6] => [2,3,4,5,7,9,8,15,6] => [2,3,4,5,6,9,8,15,7]
